# %% [markdown]
# # AUDIO-SR
#
# ### Paper - https://arxiv.org/pdf/2309.07314.pdf
# ### GitHub - https://audioldm.github.io/audiosr
#
# This is a bare minimum code to run audio SR on a custom audio clip and have that speech recording enhanced.

# %%
# !pip3 install audiosr==0.0.5
# !pip install pydub
# Out:
# Requirement already satisfied: audiosr==0.0.5 in /usr/local/lib/python3.10/dist-packages (0.0.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (2.0.1+cu118)
# Requirement already satisfied: torchaudio>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (2.0.2+cu118)
# Requirement already satisfied: torchvision>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (0.15.2+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (4.66.1)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (3.45.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (6.0.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (0.6.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (5.2.0)
# Requirement already satisfied: numpy<=1.23.5 in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (1.23.5)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (0.12.1)
# Requirement already satisfied: librosa==0.9.2 in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (0.9.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (1.11.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (1.5.3)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (1.3.7)
# Requirement already satisfied: phonemizer in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (3.2.1)
# Requirement already satisfied: torchlibrosa>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (0.1.0)
# Requirement already satisfied: transformers==4.30.2 in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (4.30.2)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (0.17.3)
# Requirement already satisfied: progressbar in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (2.5)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (6.1.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from audiosr==0.0.5) (0.9.7)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->audiosr==0.0.5) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->audiosr==0.0.5) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->audiosr==0.0.5) (1.3.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->audiosr==0.0.5) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->audiosr==0.0.5) (0.4.2)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->audiosr==0.0.5) (0.56.4)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->audiosr==0.0.5) (1.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->audiosr==0.0.5) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->audiosr==0.0.5) (3.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->audiosr==0.0.5) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->audiosr==0.0.5) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->audiosr==0.0.5) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->audiosr==0.0.5) (0.3.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->audiosr==0.0.5) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->audiosr==0.0.5) (4.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->audiosr==0.0.5) (1.15.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->audiosr==0.0.5) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->audiosr==0.0.5) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->audiosr==0.0.5) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->audiosr==0.0.5) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->audiosr==0.0.5) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->audiosr==0.0.5) (16.0.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.14.0->audiosr==0.0.5) (9.4.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->audiosr==0.0.5) (0.2.6)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (0.103.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (0.3.1)
# Requirement already satisfied: gradio-client==0.5.2 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (0.5.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (0.25.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (6.0.1)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (3.7.1)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (3.9.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (1.10.12)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (0.0.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (2.10.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (0.23.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiosr==0.0.5) (11.0.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->audiosr==0.0.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->audiosr==0.0.5) (2023.3.post1)
# Requirement already satisfied: segments in /usr/local/lib/python3.10/dist-packages (from phonemizer->audiosr==0.0.5) (2.2.1)
# Requirement already satisfied: attrs>=18.1 in /usr/local/lib/python3.10/dist-packages (from phonemizer->audiosr==0.0.5) (23.1.0)
# Requirement already satisfied: dlinfo in /usr/local/lib/python3.10/dist-packages (from phonemizer->audiosr==0.0.5) (1.2.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->audiosr==0.0.5) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->audiosr==0.0.5) (4.19.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->audiosr==0.0.5) (0.12.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->audiosr==0.0.5) (2.21)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiosr==0.0.5) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiosr==0.0.5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiosr==0.0.5) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiosr==0.0.5) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiosr==0.0.5) (3.1.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa==0.9.2->audiosr==0.0.5) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa==0.9.2->audiosr==0.0.5) (67.7.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.9.2->audiosr==0.0.5) (3.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->audiosr==0.0.5) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2->audiosr==0.0.5) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2->audiosr==0.0.5) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2->audiosr==0.0.5) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2->audiosr==0.0.5) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa==0.9.2->audiosr==0.0.5) (3.2.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio->audiosr==0.0.5) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio->audiosr==0.0.5) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->audiosr==0.0.5) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->audiosr==0.0.5) (0.27.0)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from httpx->gradio->audiosr==0.0.5) (0.18.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio->audiosr==0.0.5) (1.3.0)
# Requirement already satisfied: clldutils>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from segments->phonemizer->audiosr==0.0.5) (3.20.0)
# Requirement already satisfied: csvw>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from segments->phonemizer->audiosr==0.0.5) (3.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->audiosr==0.0.5) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio->audiosr==0.0.5) (1.1.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer->audiosr==0.0.5) (0.9.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer->audiosr==0.0.5) (6.7.0)
# Requirement already satisfied: pylatexenc in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer->audiosr==0.0.5) (2.10)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer->audiosr==0.0.5) (3.4.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer->audiosr==0.0.5) (4.9.3)
# Requirement already satisfied: babel in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->audiosr==0.0.5) (2.12.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->audiosr==0.0.5) (0.4.6)
# Requirement already satisfied: isodate in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->audiosr==0.0.5) (0.6.1)
# Requirement already satisfied: language-tags in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->audiosr==0.0.5) (1.2.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->audiosr==0.0.5) (7.0.0)
# Requirement already satisfied: rfc3986<2 in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->audiosr==0.0.5) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->audiosr==0.0.5) (4.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->audiosr==0.0.5) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->audiosr==0.0.5) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->audiosr==0.0.5) (0.10.2)

# %%
import librosa
import IPython
from IPython.core.display import display
import soundfile
import os
import soundfile
from pydub import AudioSegment

# %%
def get_wav_duration(wav_file_path):
    data, sr = soundfile.read(wav_file_path, dtype="float32")
    length = len(data) / sr

    return int(length)

# %%
import os
import torch
import logging
import argparse
from audiosr import super_resolution, build_model, save_wave

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

os.environ["TOKENIZERS_PARALLELISM"] = "true"
torch.set_float32_matmul_precision("high")


def main(args):
    audiosr = build_model(model_name=args["model_name"], device="auto")

    waveform = super_resolution(
        audiosr,
        args["input_path"],
        seed=42,
        guidance_scale=3.5,
        ddim_steps=50,
        latent_t_per_second=12.8
    )

    save_wave(waveform, args["save_path"], name="output", samplerate=48000)


def get_upscaled_audio_path(wav_file_path):
  #https://arxiv.org/pdf/2309.07314.pdf
    # parser = argparse.ArgumentParser(description='Perform super-resolution on audio files using audiosr package.')

    # parser.add_argument('-i', '--input_path', required=True, help='Path to the input waveform file.')
    # parser.add_argument('-s', '--save_path', required=True, help='Path to save the output waveform file.')
    # parser.add_argument('--model_name', choices=['basic', 'speech'], default='speech', help='Name of the model to be used.')
    # parser.add_argument('-d', '--device', default="auto", help='The device for computation. If not specified, the script will automatically choose the device based on your environment.')
    # parser.add_argument('--ddim_steps', type=int, default=50, help='The sampling step for DDIM.')
    # parser.add_argument('-gs', '--guidance_scale', type=float, default=3.5, help='Guidance scale (Large => better quality and relavancy to text; Small => better diversity).')
    # parser.add_argument('--seed', type=int, default=42, help='Change this value (any integer number) will lead to a different generation result.')
    # parser.add_argument('-il', '--input_file_list', help='A file that contains all audio files that need to perform audio super resolution.')

    args = {"input_path":wav_file_path, "model_name":"speech", "device": "cuda", "ddim_steps":50, "guidance_scale":3.5, "seed":42, "save_path": ""}
    main(args)
    return "/content/output.wav"

# %%
start = 0
end = 0
wav_file_path = "/content/Recording3.wav"
duration = get_wav_duration(wav_file_path)
upscaled_fragments_list = []
while end<duration*1000:
  print(f"duration: {duration} start: {start} end: {end}")
  end = start + 5000
  newAudio = AudioSegment.from_wav(wav_file_path)
  newAudio = newAudio[start: end]
  newAudio.export('temp.wav', format="wav")
  output_path = get_upscaled_audio_path("/content/temp.wav")
  newAudio = AudioSegment.from_wav(output_path)
  upscaled_fragments_list.append(newAudio)
  start = end
# Out:
# duration: 113 start: 0 end: 0
# Loading AudioSR: speech
# Loading model on cuda:0
# /usr/local/lib/python3.10/dist-packages/torchaudio/transforms/_transforms.py:611: UserWarning: Argument 'onesided' has been deprecated and has no influence on the behavior of this module.
#   warnings.warn(
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.61it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 5000 end: 5000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.65it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 10000 end: 10000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.71it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 15000 end: 15000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:09<00:00,  5.49it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 20000 end: 20000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:08<00:00,  5.62it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 25000 end: 25000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.78it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 30000 end: 30000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.70it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 35000 end: 35000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:09<00:00,  5.05it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 40000 end: 40000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:08<00:00,  5.77it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 45000 end: 45000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:09<00:00,  5.35it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 50000 end: 50000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.71it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 55000 end: 55000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.84it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 60000 end: 60000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:08<00:00,  5.76it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 65000 end: 65000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:09<00:00,  5.33it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 70000 end: 70000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.70it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 75000 end: 75000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.74it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 80000 end: 80000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:09<00:00,  5.23it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 85000 end: 85000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:08<00:00,  5.71it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 90000 end: 90000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:09<00:00,  5.24it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 95000 end: 95000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.67it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 100000 end: 100000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:10<00:00,  4.72it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 105000 end: 105000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:09<00:00,  5.17it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.
# duration: 113 start: 110000 end: 110000
# Loading AudioSR: speech
# Loading model on cuda:0
# DiffusionWrapper has 258.20 M params.
# Running DDIM Sampling with 50 timesteps
# DDIM Sampler: 100%|██████████| 50/50 [00:08<00:00,  5.69it/s]
#  Don't forget to try different seeds by setting --seed <int> so that AudioSR can have optimal performance on your hardware.
# Save audio to output.wav.

# %%
sound_final = upscaled_fragments_list[0]

for sound in upscaled_fragments_list[1:]:
  sound_final += sound

# %%
sound_final
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
sound_final.export("/content/recording3_audioSR.wav", format="wav")
# Out:
# <_io.BufferedRandom name='/content/recording3_audioSR.wav'>
